# %% [markdown]
# ## Mentorship - 1
#
# Sandeep Kumar:
# - 7847975728
#
#
# ### Data Analytics: (60% technical, 40% Management)
#
# (Amazon ~: 15 Base + 3 stocks = 18LPA)   ((0-3 yrs) : 9LPA -15 LPA)
#
#
#
# #### Technical skills:
#
# SQL
#
# Tableau , ClickSense
#
# Statistics (and Predictive models)
#
# Descriptive and Inferential statistics
#
# Cluster computing fundamentals
#
# Pre-processing clustering: Apache Hadoop, Map-Reduce, AWS Lambda, Kappa, Azure Datalake, Apache spark, Apache beam, apache flink, Amazon kinesis
#
# Python
#
#
#
# #### Soft skills:
#
# Domain knowledge
#
# Data story telling
#
# Business case study problem solving
#
# Critical and analytical thinking
#
#
#
# Projects:
#
# Deloitte
#
# Kaggle
#
#
# <hr>
# <hr>
#
#
# ### Data Scientist / Business Analyst/ Business Intelligence  Specialist: (3-4 yrs)
#
#
#
#  <hr>
# <hr>
#
#
#
# ### Data Engineer: (90% technical)  ((0-5 yrs) : 8LPA -21 LPA)
#
#  <hr>
# <hr>
#
#
#
# ### Machine learning engineer / AI developer (mostly technical):
#
# ((0-5 yrs) : 8/9 LPA - 12/15 LPA
#
#
#
# #### Technical skills:
#
# DB:
#
# rel:SQL, PostgreSQL, AWS Aurora ;
#
# non-rel: MongoDB, Elastic search, Cassandra
#
# Data warehouses: AWS S3, GCS, Snowflake, Hive, Impala, Azure Synopsis
#
# Cluster computing fundamentals
#
# Pre-processing clustering: Apache Hadoop, Map-Reduce, AWS Lambda, Kappa, Azure Datalake, Apache spark, Apache beam, apache flink, Amazon kinesis
#
# Data pipeline monitoring: Prometheus, Sentry, Datadog
#
# Python
#
# ML-OPS: Sagemaker, Google AI
#
# #### Openings:
# - paytm.lever
#
# #### Projects:
# -
#
#
#
#
# #### Soft skills:
#
# Domain knowledge
#
# Data story telling
#
# Business case study problem solving
#
# Critical and analytical thinking
#
#
#
# Projects:
#
# Deloitte
#
# Kaggle

# %%
# --- gcolab wrapper: list files in outputs/ ---
import os, datetime
_out_dir = 'outputs'
os.makedirs(_out_dir, exist_ok=True)
print(f"Files in {_out_dir}:")
_files = []
for _fn in os.listdir(_out_dir):
    _fp = os.path.join(_out_dir, _fn)
    if os.path.isfile(_fp):
        _st = os.stat(_fp)
        _files.append((datetime.datetime.fromtimestamp(_st.st_mtime).strftime('%Y-%m-%d %H:%M:%S'), _st.st_size, _fn))
_files.sort()
for _m, _s, _n in _files:
    if _s < 1024:
        _h = f"{_s} B"
    elif _s < 1024*1024:
        _h = f"{_s/1024:.2f} KB"
    else:
        _h = f"{_s/(1024*1024):.2f} MB"
    print(f"{_m}  {_h:>10}  {_n}")

# %%
# --- gcolab wrapper: zip outputs/ -> outputs.zip ---
import os, shutil
os.makedirs('outputs', exist_ok=True)
shutil.make_archive('outputs', 'zip', 'outputs')
print('Created outputs.zip')
